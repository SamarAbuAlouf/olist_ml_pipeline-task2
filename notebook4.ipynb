# %% [markdown]
# `EDA = Exploratory Data Analysis`

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

# %%
EDA_DIR = Path("artifacts/eda")
EDA_DIR.mkdir(parents=True, exist_ok=True)

# %%
train = pd.read_csv("artifacts/train.csv")
print("Training data loaded successfully.")
print("Shape:", train.shape)
# Out:
# Training data loaded successfully.
# Shape: (67533, 22)

# %%
train.head()
# Out:
#                            order_id                       customer_id  \
# 0  bfbd0f9bdef84302105ad712db648a6c  86dc2ffce2dfff336de2f386a786e574
# 1  3b697a20d9e427646d92567910af6d57  355077684019f7f60a031656bd7262b8
# 2  be5bc2f0da14d8071e2d45451ad119d9  7ec40b22510fdbea1b08921dd39e63d8
# 3  65d1e226dfaeb8cdc42f665422522d14  70fc57eeae292675927697fe03ad3ff5
# 4  a41c8759fbe7aab36ea07e038b2d4465  6f989332712d3222b6571b1cf5b835ce
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2016-09-15 12:16:38  2016-09-15 12:16:38
# 1    delivered      2016-10-03 09:44:50  2016-10-06 15:50:54
# 2    delivered      2016-10-03 16:56:50  2016-10-06 16:03:44
# 3     canceled      2016-10-03 21:01:41  2016-10-04 10:18:57
# 4    delivered      2016-10-03 21:13:36  2016-10-05 03:11:49
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2016-11-07 17:11:53           2016-11-09 07:47:38
# 1          2016-10-23 14:02:13           2016-10-26 14:02:13
# 2          2016-10-21 16:33:46           2016-10-27 18:19:38
# 3          2016-10-25 12:14:28           2016-11-08 10:58:34
# 4          2016-10-25 11:57:59           2016-11-03 10:58:07
#
#   order_estimated_delivery_date  item_count  unique_products  ...  \
# 0                    2016-10-04         3.0              1.0  ...
# 1                    2016-10-27         1.0              1.0  ...
# 2                    2016-11-07         1.0              1.0  ...
# 3                    2016-11-25         1.0              1.0  ...
# 4                    2016-11-29         1.0              1.0  ...
#
#    total_freight  avg_item_price  payment_count  total_payment_value  \
# 0           8.49           44.99            NaN                  NaN
# 1          15.56           29.90            1.0                45.46
# 2          17.19           21.90            1.0                39.09
# 3          14.11           21.50            1.0                35.61
# 4          17.24           36.49            1.0                53.73
#
#    max_installments                customer_unique_id  \
# 0               NaN  830d5b7aaa3b6f1e9ad63703bec97d23
# 1               1.0  32ea3bdedab835c3aa6cb68ce66565ef
# 2               1.0  2f64e403852e6893ae37485d5fcacdaf
# 3               1.0  b8b8726af116a5cfb35b0315ecef9172
# 4               1.0  61db744d2f835035a5625b59350c6b63
#
#    customer_zip_code_prefix         customer_city  customer_state is_late
# 0                     14600  sao joaquim da barra              SP       1
# 1                      4106             sao paulo              SP       0
# 2                     98280               panambi              RS       0
# 3                     22770        rio de janeiro              RJ       0
# 4                     90040          porto alegre              RS       0
#
# [5 rows x 22 columns]

# %%
train.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 67533 entries, 0 to 67532
# Data columns (total 22 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       67533 non-null  str
#  1   customer_id                    67533 non-null  str
#  2   order_status                   67533 non-null  str
#  3   order_purchase_timestamp       67533 non-null  str
#  4   order_approved_at              67519 non-null  str
#  5   order_delivered_carrier_date   67532 non-null  str
#  6   order_delivered_customer_date  67533 non-null  str
#  7   order_estimated_delivery_date  67533 non-null  str
#  8   item_count                     67533 non-null  float64
#  9   unique_products                67533 non-null  float64
#  10  unique_sellers                 67533 non-null  float64
#  11  total_price                    67533 non-null  float64
#  12  total_freight                  67533 non-null  float64
#  13  avg_item_price                 67533 non-null  float64
#  14  payment_count                  67532 non-null  float64
#  15  total_payment_value            67532 non-null  float64
#  16  max_installments               67532 non-null  float64
#  17  customer_unique_id             67533 non-null  str
#  18  customer_zip_code_prefix       67533 non-null  int64
#  19  customer_city                  67533 non-null  str
#  20  customer_state                 67533 non-null  str
#  21  is_late                        67533 non-null  int64
# dtypes: float64(9), int64(2), str(11)
# memory usage: 24.4 MB

# %%
dtype_summary = pd.DataFrame({
    "column": train.columns,
    "dtype": train.dtypes.astype(str).values,
    "missing": train.isna().sum().values,
    "unique_values": train.nunique().values})
dtype_summary
# Out:
#                            column    dtype  missing  unique_values
# 0                        order_id      str        0          67533
# 1                     customer_id      str        0          67533
# 2                    order_status      str        0              2
# 3        order_purchase_timestamp      str        0          67155
# 4               order_approved_at      str       14          63153
# 5    order_delivered_carrier_date      str        1          63242
# 6   order_delivered_customer_date      str        0          66958
# 7   order_estimated_delivery_date      str        0            356
# 8                      item_count  float64        0             17
# 9                 unique_products  float64        0              7
# 10                 unique_sellers  float64        0              5
# 11                    total_price  float64        0           5842
# 12                  total_freight  float64        0           6222
# 13                 avg_item_price  float64        0           5317
# 14                  payment_count  float64        1             19
# 15            total_payment_value  float64        1          21015
# 16               max_installments  float64        1             22
# 17             customer_unique_id      str        0          65401
# 18       customer_zip_code_prefix    int64        0          13748
# 19                  customer_city      str        0           3747
# 20                 customer_state      str        0             27
# 21                        is_late    int64        0              2

# %%
id_columns = [
    col for col in train.columns
    if col.endswith("_id")]
print("ID columns:")
print(id_columns)
# Out:
# ID columns:
# ['order_id', 'customer_id', 'customer_unique_id']

# %%
for col in id_columns:
    print(f"\n{col}")
    print("Unique:", train[col].nunique())
    print("Missing:", train[col].isna().sum())
    print("Duplicated:", train[col].duplicated().sum())
# Out:
# order_id
# Unique: 67533
# Missing: 0
# Duplicated: 0
#
# customer_id
# Unique: 67533
# Missing: 0
# Duplicated: 0
#
# customer_unique_id
# Unique: 65401
# Missing: 0
# Duplicated: 2132

# %%
# Missing Values
missing_summary = pd.DataFrame({
    "missing_count": train.isna().sum(),
    "missing_percentage": train.isna().mean() * 100})
missing_summary = missing_summary[
    missing_summary["missing_count"] > 0 
    ].sort_values("missing_percentage", ascending=False)
missing_summary
# Out:
#                               missing_count  missing_percentage
# order_approved_at                        14            0.020731
# order_delivered_carrier_date              1            0.001481
# payment_count                             1            0.001481
# total_payment_value                       1            0.001481
# max_installments                          1            0.001481

# %%
# Convert date columns before date/categorical EDA
date_columns = [
    "order_purchase_timestamp",
    "order_approved_at",
    "order_delivered_customer_date",
    "order_estimated_delivery_date"]
for col in date_columns:
    if col in train.columns:
        train[col] = pd.to_datetime(train[col], errors="coerce")
print("Date columns converted successfully.")
# Out:
# Date columns converted successfully.

# %%
if {"order_purchase_timestamp",
    "order_delivered_customer_date"}.issubset(train.columns):
    train["delivery_days"] = (
        train["order_delivered_customer_date"]
        - train["order_purchase_timestamp"]).dt.total_seconds() / (60 * 60 * 24)

# %%
# Numerical Features
numeric_columns = train.select_dtypes(
    include=["int64", "float64"]).columns.tolist()
numeric_columns
# Out:
# ['item_count',
#  'unique_products',
#  'unique_sellers',
#  'total_price',
#  'total_freight',
#  'avg_item_price',
#  'payment_count',
#  'total_payment_value',
#  'max_installments',
#  'customer_zip_code_prefix',
#  'is_late',
#  'delivery_days']

# %%
#  is_late - label
numeric_features = [
    col for col in numeric_columns
    if col != "is_late"]
print(numeric_features)
# Out:
# ['item_count', 'unique_products', 'unique_sellers', 'total_price', 'total_freight', 'avg_item_price', 'payment_count', 'total_payment_value', 'max_installments', 'customer_zip_code_prefix', 'delivery_days']

# %%
train[numeric_features].describe().T
# Out:
#                             count          mean           std          min  \
# item_count                67533.0      1.142079      0.541635     1.000000
# unique_products           67533.0      1.037715      0.222223     1.000000
# unique_sellers            67533.0      1.012053      0.114812     1.000000
# total_price               67533.0    135.884499    205.187627     2.290000
# total_freight             67533.0     22.244256     19.999582     0.000000
# avg_item_price            67533.0    124.234649    185.653751     1.514286
# payment_count             67532.0      1.047622      0.397212     1.000000
# total_payment_value       67532.0    158.167657    214.277783    10.070000
# max_installments          67532.0      2.974397      2.755007     1.000000
# customer_zip_code_prefix  67533.0  36010.131728  29908.266914  1004.000000
# delivery_days             67533.0     13.824767     10.249351     0.533414
#
#                                    25%           50%           75%  \
# item_count                    1.000000      1.000000      1.000000
# unique_products               1.000000      1.000000      1.000000
# unique_sellers                1.000000      1.000000      1.000000
# total_price                  45.900000     85.000000    149.900000
# total_freight                14.100000     16.790000     23.700000
# avg_item_price               41.000000     78.970000    139.900000
# payment_count                 1.000000      1.000000      1.000000
# total_payment_value          61.630000    104.190000    175.485000
# max_installments              1.000000      2.000000      4.000000
# customer_zip_code_prefix  12061.000000  25959.000000  60360.000000
# delivery_days                 7.450845     11.475266     17.189977
#
#                                    max
# item_count                   21.000000
# unique_products               7.000000
# unique_sellers                5.000000
# total_price               13440.000000
# total_freight              1002.290000
# avg_item_price             6735.000000
# payment_count                26.000000
# total_payment_value       13664.080000
# max_installments             24.000000
# customer_zip_code_prefix  99980.000000
# delivery_days               209.628611

# %%
# Skew
skewness = train[numeric_features].skew().sort_values(ascending=False)
skewness
# Out:
# payment_count               22.420165
# total_price                 10.719309
# unique_sellers              10.525258
# total_payment_value         10.149896
# total_freight                8.584291
# item_count                   8.106935
# avg_item_price               7.802797
# unique_products              7.675360
# delivery_days                3.867077
# max_installments             1.592864
# customer_zip_code_prefix     0.739793
# dtype: float64

# %%
for col in numeric_features[:5]:
    plt.figure(figsize=(8, 4))
    sns.histplot(train[col].dropna(), kde=True)
    plt.title(f"Distribution of {col}")
    plt.xlabel(col)
    plt.ylabel("Count")
    plt.tight_layout()
    plt.savefig(
        EDA_DIR / f"distribution_{col}.png",
        bbox_inches="tight")
    plt.show()
    plt.close()

# %%
# Outliers
for col in numeric_features:
    plt.figure(figsize=(8, 3))
    sns.boxplot(x=train[col]) 
    plt.title(f"Boxplot of {col}")
    plt.tight_layout()
    plt.savefig(
        EDA_DIR / f"boxplot_{col}.png",
        bbox_inches="tight")
    plt.show()
    plt.close()

# %%
outlier_summary = []
for col in numeric_features:
    Q1 = train[col].quantile(0.25)
    Q3 = train[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = train[
        (train[col] < lower_bound) |
        (train[col] > upper_bound)]
    outlier_summary.append({
        "feature": col,
        "outlier_count": len(outliers),
        "outlier_percentage": round(len(outliers) / len(train) * 100, 2)})
outlier_summary = pd.DataFrame(outlier_summary)
outlier_summary
# Out:
#                      feature  outlier_count  outlier_percentage
# 0                 item_count           6759               10.01
# 1            unique_products           2210                3.27
# 2             unique_sellers            776                1.15
# 3                total_price           5361                7.94
# 4              total_freight           6629                9.82
# 5             avg_item_price           5109                7.57
# 6              payment_count           2129                3.15
# 7        total_payment_value           5308                7.86
# 8           max_installments           4677                6.93
# 9   customer_zip_code_prefix              0                0.00
# 10             delivery_days           3448                5.11

# %%
# Categorical Features
categorical_columns = [
    col for col in train.select_dtypes(include=["object"]).columns
    if col not in id_columns]
print("Categorical columns:")
print(categorical_columns)
# Out:
# Categorical columns:
# ['order_status', 'order_delivered_carrier_date', 'customer_city', 'customer_state']
# C:\Users\rosto\AppData\Local\Temp\ipykernel_12264\674246471.py:3: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   col for col in train.select_dtypes(include=["object"]).columns

# %%
# Cardinality  -- (unique values) --
cardinality = (
    train[categorical_columns]
    .nunique()
    .sort_values(ascending=False))
cardinality
# Out:
# order_delivered_carrier_date    63242
# customer_city                    3747
# customer_state                     27
# order_status                        2
# dtype: int64

# %%
for col in categorical_columns:
    print(f"\n **** {col} **** ")
    print(train[col].value_counts(dropna=False).head(10))
# Out:
#  **** order_status ****
# order_status
# delivered    67527
# canceled         6
# Name: count, dtype: int64
#
#  **** order_delivered_carrier_date ****
# order_delivered_carrier_date
# 2016-10-14 18:00:00    11
# 2017-07-26 11:07:51     7
# 2017-03-21 09:17:46     6
# 2017-05-24 12:14:23     5
# 2017-07-19 19:22:35     5
# 2017-02-06 11:54:29     4
# 2017-03-23 08:42:41     4
# 2017-04-27 11:24:46     4
# 2017-05-09 14:19:21     4
# 2017-05-23 07:13:36     4
# Name: count, dtype: int64
#
#  **** customer_city ****
# customer_city
# sao paulo                9921
# rio de janeiro           4780
# belo horizonte           1869
# brasilia                 1395
# curitiba                 1020
# porto alegre              975
# campinas                  967
# salvador                  823
# guarulhos                 724
# sao bernardo do campo     622
# Name: count, dtype: int64
#
#  **** customer_state ****
# customer_state
# SP    27204
# RJ     8967
# MG     8130
# RS     3912
# PR     3461
# SC     2577
# BA     2307
# ES     1445
# GO     1409
# DF     1404
# Name: count, dtype: int64

# %%
# Rare Categories
# A category is considered rare if it appears in less than 1% of the training rows.
rare_category_summary = []
for col in categorical_columns:
    frequencies = train[col].value_counts(normalize=True, dropna=False)
    rare_categories = frequencies[frequencies < 0.01]
    rare_category_summary.append({
        "feature": col,
        "rare_category_count": len(rare_categories),
        "rare_row_count": int(train[col].isin(rare_categories.index).sum()),
        "rare_row_percentage": round(
            train[col].isin(rare_categories.index).mean() * 100, 2)})
rare_category_summary = pd.DataFrame(rare_category_summary)
rare_category_summary
# Out:
#                         feature  rare_category_count  rare_row_count  \
# 0                  order_status                    1               6
# 1  order_delivered_carrier_date                63243           67533
# 2                 customer_city                 3738           45059
# 3                customer_state                   14            3934
#
#    rare_row_percentage
# 0                 0.01
# 1               100.00
# 2                66.72
# 3                 5.83

# %%
label_counts = train["is_late"].value_counts()
print(label_counts)
print("\nPercentage:")
print(train["is_late"].value_counts(normalize=True) * 100)
# Out:
# is_late
# 0    61436
# 1     6097
# Name: count, dtype: int64
#
# Percentage:
# is_late
# 0    90.971821
# 1     9.028179
# Name: proportion, dtype: float64

# %%
# Categorical vs Label
state_late_rate = (
    train.groupby("customer_state")["is_late"]
    .mean()
    .sort_values(ascending=False))
state_late_rate
# Out:
# customer_state
# AL    0.278523
# MA    0.215328
# CE    0.182489
# RR    0.172414
# SE    0.170732
# PI    0.166667
# RJ    0.165830
# BA    0.149978
# PA    0.133705
# ES    0.132872
# TO    0.131980
# PB    0.127027
# RN    0.123209
# SC    0.119519
# PE    0.119069
# MS    0.117530
# GO    0.095813
# RS    0.086656
# MT    0.085938
# DF    0.079772
# MG    0.062977
# AP    0.058824
# SP    0.055948
# PR    0.054320
# AM    0.047619
# AC    0.045455
# RO    0.037838
# Name: is_late, dtype: float64

# %%
plt.figure(figsize=(10, 5))
state_late_rate.sort_values().plot(kind="barh")
plt.title("Late Delivery Rate by Customer State")
plt.xlabel("Late Rate")
plt.ylabel("Customer State")
plt.tight_layout()
plt.savefig(
    EDA_DIR / "late_rate_by_customer_state.png",
    bbox_inches="tight")
plt.show()
plt.close()

# %%
for col in ["customer_state", "seller_state"]:
    if col in train.columns:
        result = (
            train.groupby(col)["is_late"]
            .mean()
            .sort_values(ascending=False))
        print(f"\nLate rate by {col}:")
        print(result)
# Out:
# Late rate by customer_state:
# customer_state
# AL    0.278523
# MA    0.215328
# CE    0.182489
# RR    0.172414
# SE    0.170732
# PI    0.166667
# RJ    0.165830
# BA    0.149978
# PA    0.133705
# ES    0.132872
# TO    0.131980
# PB    0.127027
# RN    0.123209
# SC    0.119519
# PE    0.119069
# MS    0.117530
# GO    0.095813
# RS    0.086656
# MT    0.085938
# DF    0.079772
# MG    0.062977
# AP    0.058824
# SP    0.055948
# PR    0.054320
# AM    0.047619
# AC    0.045455
# RO    0.037838
# Name: is_late, dtype: float64

# %%
# Numerical Feature vs Label
train.groupby("is_late")[numeric_features].mean().T
# Out:
# is_late                              0             1
# item_count                    1.144834      1.114319
# unique_products               1.039228      1.022470
# unique_sellers                1.012989      1.002624
# total_price                 134.506741    149.767376
# total_freight                21.950632     25.202941
# avg_item_price              122.632952    140.374029
# payment_count                 1.048359      1.040190
# total_payment_value         156.496706    175.007633
# max_installments              2.959486      3.124672
# customer_zip_code_prefix  35629.392213  39846.627194
# delivery_days                11.772115     34.508173

# %%
# Correlation
correlation = train[numeric_features + ["is_late"]].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(
    correlation,
    annot=True,fmt=".2f")
plt.title("Correlation Matrix")
plt.tight_layout()
plt.savefig(
    EDA_DIR / "correlation_matrix.png",
    bbox_inches="tight")
plt.show()
plt.close()

# %%
# Days of Week
if "order_purchase_timestamp" in train.columns:
    train["purchase_day_of_week"] = (
        train["order_purchase_timestamp"].dt.day_name())
    day_late_rate = (
        train.groupby("purchase_day_of_week")["is_late"]
        .mean())    
    day_late_rate

# %%
plt.figure(figsize=(9, 5))
day_late_rate.plot(kind="bar")
plt.title("Late Delivery Rate by Purchase Day")
plt.xlabel("Day of Week")
plt.ylabel("Late Rate")
plt.tight_layout()
plt.savefig(
    EDA_DIR / "late_rate_by_day_of_week.png",
    bbox_inches="tight")
plt.show()
plt.close()

# %%
# Geographic Analysis
customer_state_analysis = (
    train.groupby("customer_state")["is_late"]
    .agg(["count", "mean"])
    .sort_values("mean", ascending=False))
customer_state_analysis
# Out:
#                 count      mean
# customer_state
# AL                298  0.278523
# MA                548  0.215328
# CE                948  0.182489
# RR                 29  0.172414
# SE                246  0.170732
# PI                348  0.166667
# RJ               8967  0.165830
# BA               2307  0.149978
# PA                718  0.133705
# ES               1445  0.132872
# TO                197  0.131980
# PB                370  0.127027
# RN                349  0.123209
# SC               2577  0.119519
# PE               1117  0.119069
# MS                502  0.117530
# GO               1409  0.095813
# RS               3912  0.086656
# MT                640  0.085938
# DF               1404  0.079772
# MG               8130  0.062977
# AP                 51  0.058824
# SP              27204  0.055948
# PR               3461  0.054320
# AM                105  0.047619
# AC                 66  0.045455
# RO                185  0.037838

# %%
train["purchase_month"] = train["order_purchase_timestamp"].dt.month
monthly_late_rate = (
    train.groupby("purchase_month")["is_late"].mean())
print(monthly_late_rate)
# Out:
# purchase_month
# 1     0.062284
# 2     0.134243
# 3     0.171536
# 4     0.070236
# 5     0.036107
# 6     0.038596
# 7     0.034349
# 8     0.033150
# 9     0.052277
# 10    0.050548
# 11    0.143112
# 12    0.083787
# Name: is_late, dtype: float64

# %%
plt.figure(figsize=(10, 5))
monthly_late_rate.plot(kind="bar")
plt.title("Late Delivery Rate by Purchase Month")
plt.xlabel("Purchase Month")
plt.ylabel("Late Rate")
plt.tight_layout()
plt.savefig(
    EDA_DIR / "late_rate_by_month.png",
    bbox_inches="tight")
plt.show()
plt.close()

# %%
selected_features = [
    "order_purchase_timestamp",
    "order_approved_at",
    "order_estimated_delivery_date",
    "item_count",
    "unique_products",
    "unique_sellers",
    "total_price",
    "total_freight",
    "avg_item_price",
    "payment_count",
    "total_payment_value",
    "max_installments",
    "customer_zip_code_prefix",
    "customer_state"]

# %%
# Save selected features
selected_features_df = pd.DataFrame({"feature": selected_features})
selected_features_df.to_csv(
    EDA_DIR / "selected_features.csv",index=False)
print("Selected features saved:", EDA_DIR / "selected_features.csv")
# Out:
# Selected features saved: artifacts\eda\selected_features.csv

# %% [markdown]
# ## EDA Summary
#
# The EDA was performed on the training dataset only.
#
# - The dataset contains numerical, categorical, ID, and date-related features.
# - Missing values were identified and will be handled during preprocessing.
# - Numerical features were examined using descriptive statistics, distributions, skewness, and outlier analysis.
# - Categorical features were examined for cardinality, frequent categories, and rare categories.
# - Relationships between features and the target `is_late` were analyzed.
# - Purchase date/time, day-of-week, and month patterns were examined.
# - Features based on information available only after delivery were excluded from the selected feature list to reduce leakage risk.
#
# Based on the EDA, the selected features are:
#
# - `order_purchase_timestamp`
# - `order_approved_at`
# - `order_estimated_delivery_date`
# - `item_count`
# - `unique_products`
# - `unique_sellers`
# - `total_price`
# - `total_freight`
# - `avg_item_price`
# - `payment_count`
# - `total_payment_value`
# - `max_installments`
# - `customer_zip_code_prefix`
# - `customer_state`

# %%
# Save EDA summary
summary_text = """EDA Summary
The EDA was performed on the training dataset only.
- Numerical, categorical, ID, and date-related features were inspected.
- Missing values were identified and will be handled during preprocessing.
- Numerical features were examined using descriptive statistics, distributions, skewness, and outlier analysis.
- Categorical features were examined using cardinality, frequent categories, and rare-category analysis.
- Relationships between features and the target `is_late` were analyzed.
- Purchase date/time features and day-of-week/month patterns were examined.
- Features based on information available only after delivery were excluded from the selected feature list to reduce leakage risk.
Selected features:
""" + "\n".join(f"- {f}" for f in selected_features)
with open(EDA_DIR / "eda_summary.txt", "w", encoding="utf-8") as f:
    f.write(summary_text)
print("EDA summary saved:", EDA_DIR / "eda_summary.txt")
print("\nSaved EDA artifacts:")
for file in sorted(EDA_DIR.iterdir()):
    print(file.name)
# Out:
# EDA summary saved: artifacts\eda\eda_summary.txt
#
# Saved EDA artifacts:
# boxplot_avg_item_price.png
# boxplot_customer_zip_code_prefix.png
# boxplot_delivery_days.png
# boxplot_item_count.png
# boxplot_max_installments.png
# boxplot_payment_count.png
# boxplot_total_freight.png
# boxplot_total_payment_value.png
# boxplot_total_price.png
# boxplot_unique_products.png
# boxplot_unique_sellers.png
# correlation_matrix.png
# distribution_item_count.png
# distribution_total_freight.png
# distribution_total_price.png
# distribution_unique_products.png
# distribution_unique_sellers.png
# eda_summary.txt
# late_rate_by_customer_state.png
# late_rate_by_day_of_week.png
# late_rate_by_month.png
# selected_features.csv
